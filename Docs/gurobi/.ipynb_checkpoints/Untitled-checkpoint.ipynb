# %%
instance_file = open("../../instances/vrppl/25/C101_co_25.txt","r")

lines = instance_file.readlines()

qty_customer = lines[0].strip().split(" ")[0]
qty_locker = lines[0].strip().split(" ")[1]

demmands = list()

for demmand in range(1,qty_customer):
    demmands.append(demmand)
    

print(qty_customer, qty_locker)
print(demmands)
print([line.strip() for line in lines])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       6 qty_locker = lines[0].strip().split(" ")[1]
#       8 demmands = list()
# ---> 10 for demmand in range(1,qty_customer):
#      11     demmands.append(demmand)
#      14 print(qty_customer, qty_locker)
#
# TypeError: 'str' object cannot be interpreted as an integer
