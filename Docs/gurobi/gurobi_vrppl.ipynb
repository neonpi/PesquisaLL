# %%
import instance_builder as ib
import gurobipy as gp
instance = ib.build_instance("../../instances/vrppl/inst_test")
# Out:
# BUILDING INSTANCE inst_test
# Qty customer:10
# Qty locker:2
# Max vehicles:2
# Vehicle capacity:200
# BUILD FINISHED

# %%
qty_vehicles = 3

demands = [node['demand'] for node in instance['nodes']]

#Rotulos

# #Nos
nodes = [node['label'] for node in instance['nodes']]

#Veiculos
vehicles = list()
for i in range(qty_vehicles):
    vehicles.append(f"v_{i}")

#Arestas
edges = list()
for i in range(instance['qty_nodes']):
    for j in range(instance['qty_nodes']):
        edges.append(f"x_{nodes[i],nodes[j]}")

#Criando dicts
costs = dict()
for i in range(instance['qty_nodes']):
    for j in range(instance['qty_nodes']):
        label=f"x_{nodes[i],nodes[j]}"
        costs[label] = instance['distances'][i][j]
# print(costs,'\n')
m = gp.Model()
m.setParam(gp.GRB.Param.OutputFlag,0)

x = m.addVars(vehicles, edges, vtype = gp.GRB.BINARY)

# print(x)
m.setObjective(
    gp.quicksum(costs[edge] * x[vehicle,edge] for edge in edges for vehicle in vehicles),
    sense = gp.GRB.MINIMIZE
)

m.optimize()
print("Valor Total", m.objVal)
# print(m.getObjective())

for vehicle in vehicles:
    print(vehicle)
    for edge in edges:
        if
# print(x)
# #Clientes
# rot_customers = [node['label'] for node in instance['customers']]

# #Lockers
# rot_lockers = [node['label'] for node in instance['lockers']]


# print(costs)

# print(vehicles)
# print(edges)
# print(vehicles)
# print(demands)
# print(rot_nodes)
# print(rot_customers)
# print(rot_lockers)
# Out:
# Valor Total 0.0
# v_0
# v_1
# v_2
# ...
